# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.2

# %%
series = pd.Series([1,2,3,4,5])
new_series = series

# %%
print(new_series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
sales = [150,200,100]
month = ['Jan','Feb','Mar']
s = pd.Series(sales, index=month)
print(s)
# Out:
# Jan    150
# Feb    200
# Mar    100
# dtype: int64

# %%
#dict
currencies = {
    'usd':88.3,
    'eur':95.1,
    'cny':11.4 
}
s_curr = pd.Series(currencies)
print(s_curr)
# Out:
# usd    88.3
# eur    95.1
# cny    11.4
# dtype: float64

# %%
s = pd.Series([10,20,30], name='Temperature')
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# Name: Temperature, dtype: int64

# %%
data = [500,600,700]
years = [2010, 2011, 2012]
s_years = pd.Series(data, index=years)
print(s_years)
# Out:
# 2010    500
# 2011    600
# 2012    700
# dtype: int64
