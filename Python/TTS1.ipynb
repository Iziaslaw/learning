# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("Технологии в области машинного обучения за последний год развиваются с потрясающей скоростью. Всё больше компаний делятся своими наработками, тем самым открывая новые возможности для создания умных цифровых помощников")
engine.runAndWait()
print("Yes")
# Out:
# Yes
