# %%
import tkinter as tk

root = tk.Tk()
root.title("Приложение с иконкой")
root.geometry("300x200")

# Установка иконки из файла .png
icon = tk.PhotoImage(file="images/logo.png")
root.iconphoto(False, icon)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[7], line 9
#       5 root.geometry("300x200")
#       6
#       7 # Установка иконки из файла .png
#       8 icon = tk.PhotoImage(file="images/logo.png")
# ----> 9 root.iconphoto(False, icon)
#      10
#      11 root.mainloop()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\tkinter\__init__.py:2341, in Wm.wm_iconphoto(self, default, *args)
#    2339     self.tk.call('wm', 'iconphoto', self._w, "-default", *args)
#    2340 else:
# -> 2341     self.tk.call('wm', 'iconphoto', self._w, *args)
#
# TclError: can't use "pyimage4" as iconphoto: not a photo image
