# %%
#question 11
W1 = float(60) #мощность лампочки, Ватт
W2 = float(0.01) #потеря на проводах при W1, Ватт
W3 = float(100) #мощность другой лампочки, Ватт
U = float(220) #напряжение Вольт
I1 = W1/U
r = W2/I1**2
I2 = W3/U
W4 = W2 * (W3/W1)**2
W41 = I2**2 *r
print(r,I2,W4,W41)
# Out:
# 0.13444444444444448 0.45454545454545453 0.027777777777777783 0.027777777777777783

# %%
'''Два одинаковых вольтметра, соединенных последовательно, при
подключении к источнику тока показывают напряжение U1 = 4,5 B
каждый. Если к тому же источнику подключить один вольтметр, он
показывает напряжение U2 = 8 В. Чему равна ЭДС источника?'''
U1 = float(4.5)
U2 = float(8.0)
E1 = 2*U1 + U1*((2*U1 - U2) / (2*U2 - U1))
#E2 = (2*U1*U2)/(2*U2-U1)
print(E1)
# Out:
# 9.391304347826086
